# %%
#string functions

# %%
name = "Nitish"

# %%
name.lower()
# Out:
# 'nitish'

# %%
name
# Out:
# 'Nitish'

# %%
name=name.lower()

# %%
name
# Out:
# 'nitish'

# %%
name.upper()
# Out:
# 'NITISH'

# %%
name.title()
# Out:
# 'Nitish'

# %%
name.swapcase()
# Out:
# 'NITISH'

# %%
name = "Nitish"

# %%
name.swapcase()
# Out:
# 'nITISH'

# %%
name.isupper()
# Out:
# False

# %%
name.islower()
# Out:
# False

# %%
name.istitle()
# Out:
# True

# %%
name1 = "ok"
name2 = "123"
name3 = "ok123"

# %% [markdown]
# name1.isalpha()

# %%
name1.isalpha()
# Out:
# True

# %%
name2.isalpha()
# Out:
# False

# %%
name3.isalpha()
# Out:
# False

# %%
name1.isdigit()
# Out:
# False

# %%
name2.isdigit()
# Out:
# True

# %%
name3.isdigit()
# Out:
# False

# %%
name3.isalnum()
# Out:
# True

# %%
name = " Pune "

# %%
print(name)
# Out:
#  Pune

# %%
name.startswith(" P")
# Out:
# True

# %%
name.endswith("e ")
# Out:
# True

# %%
name.endswith(" Pune ")
# Out:
# True

# %%
name.startswith(" Pune ")
# Out:
# True

# %%
name.startswith(" ")
# Out:
# True

# %%
name.lstrip()
# Out:
# 'Pune '

# %%
name.rstrip()
# Out:
# ' Pune'

# %%
name.strip()
# Out:
# 'Pune'

# %%
len(name)
# Out:
# 6

# %%
name.replace('u','o')
# Out:
# ' Pone '

# %% [markdown]
# # operators

# %%
#arithmetic

# %%
a=25
b=8

# %%
a+b
# Out:
# 33

# %%
a-b
# Out:
# 17

# %%
a*b
# Out:
# 200

# %%
a/b
# Out:
# 3.125

# %%
a**b
# Out:
# 152587890625

# %%
a%b
# Out:
# 1

# %%
a//b
# Out:
# 3

# %%
b/a
# Out:
# 0.32

# %%
b//a
# Out:
# 0

# %%
b%a
# Out:
# 8

# %%
#assignment

# %%
a = 6
a
# Out:
# 6

# %%
a = a + 2
a
# Out:
# 8

# %%
a += 2
a
# Out:
# 10

# %%
a -= 2

# %%
a
# Out:
# 8

# %%
a *= 2
a
# Out:
# 16

# %%
a /= 2

# %%
a
# Out:
# 8.0

# %%
a %= 2

# %%
a
# Out:
# 0.0

# %%
a **= 2
a
# Out:
# 0.0

# %%
a = 5
a
# Out:
# 5

# %%
a //= 2
a
# Out:
# 2

# %%
#comparison

# %%
a = 25
b = 6

# %%
a
b
# Out:
# 6

# %%
a
# Out:
# 25

# %%
b
# Out:
# 6

# %%
a > b
# Out:
# True

# %%
a < b
# Out:
# False

# %%
a == b
# Out:
# False

# %%
a <= b
# Out:
# False

# %%
a >= b
# Out:
# True

# %%
a != b
# Out:
# True

# %%
#logical

# %%
a = True
b = False

# %%
a and b
# Out:
# False

# %%
a or b
# Out:
# True

# %%
not a
# Out:
# False

# %%
not b
# Out:
# True

# %%
#identity is,is not

# %%
a = 5
b = 5

# %%
a is b
# Out:
# True

# %%
id(a), id(b)
# Out:
# (140728147289128, 140728147289128)

# %%
a = [3, 4]
b = [3, 4]

# %%
a is b
# Out:
# False

# %%
id(a), id(b)
# Out:
# (1856206739520, 1856206392832)

# %%
a is not b
# Out:
# True

# %%
z = a

# %%
z is a
# Out:
# True

# %%
z
# Out:
# [3, 4]

# %%
a.append(10)

# %%
a
# Out:
# [3, 4, 10]

# %%
z
# Out:
# [3, 4, 10]

# %%
#membership selection in

# %%
l = [4, 6, 19, 10]

# %%
6 in l
# Out:
# True

# %%
2 in l
# Out:
# False

# %%
3 not in l
# Out:
# True

# %% [markdown]
# # Precedence and association

# %%
#BODMAS

# %%
5 + 2 - 10
# Out:
# -3

# %%
(4 - 2) ** 2
# Out:
# 4

# %%
2 ** 2 ** 3
# Out:
# 256

# %%
2 ** 3 // 2
# Out:
# 4

# %%
#print function

# %%
name = "Geet"
marks = 76.57

# %%
print("My name is", name, "and my marks are", marks)
# Out:
# My name is Geet and my marks are 76.57

# %%
print("My name is %s and my marks are %i" %(name, marks))
# Out:
# My name is Geet and my marks are 76

# %%
print(f"My name is {name} and my marks are {marks}")
# Out:
# My name is Geet and my marks are 76.57

# %%
#dir and help

# %%
dir(name)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
help(name.strip)
# Out:
# Help on built-in function strip:
#
# strip(chars=None, /) method of builtins.str instance
#     Return a copy of the string with leading and trailing whitespace removed.
#
#     If chars is given and not None, remove characters in chars instead.

# %%
#ascii

# %%
ord("a")
# Out:
# 97

# %%
ord("A")
# Out:
# 65

# %%
ord("s")
# Out:
# 115

# %% [raw]
# chr(35)

# %%
chr(35)
# Out:
# '#'

# %%
chr(115)
# Out:
# 's'

# %%
num1 = 34
num2 = 44.56
num3 = "ok"

# %%
float(num1)
# Out:
# 34.0

# %%
int(num2)
# Out:
# 44

# %%
str(num2)
# Out:
# '44.56'

# %%
int(num3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 int(num3)
#
# ValueError: invalid literal for int() with base 10: 'ok'

# %%
#user input

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = a + b
print(c)
# Out:
# Enter first number:  5
# Enter second number:  3
# 8

# %%
time = int(input("Enter the time in seconds: "))
hours= time // 3600
minutes = (time % 3600) // 60
seconds = time % 60
print(f"{hours:02d}:{minutes:02d}:{seconds:02d}")
# Out:
# Enter the time in seconds:  3665
# 01:01:05
