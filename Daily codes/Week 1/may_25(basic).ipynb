# %%
print('Hello World')
# Out:
# Hello World

# %% [markdown]
# # Identifiers

# %%
name = "riya"

# %%
name
# Out:
# 'riya'

# %%
rate_of_interest = 5

# %%
rate_of_interest
# Out:
# 5

# %%
Pass = 2

# %%
Pass
# Out:
# 2

# %%
name = "riya"

# %%
name
# Out:
# 'riya'

# %%
num = 12
num1 = 25.45
name = "siya"

# %%
type(num)
# Out:
# int

# %%
type(num1)
# Out:
# float

# %%
type(name)
# Out:
# str

# %%
num = 23e4

# %%
num
# Out:
# 230000.0

# %%
sent = "I love Python Programming"

# %%
sent
# Out:
# 'I love Python Programming'

# %%
print(sent)
# Out:
# I love Python Programming

# %%
sent1 = "I love 'Python' Programming"

# %%
print(sent1)
# Out:
# I love 'Python' Programming

# %%
sent2 = 'I love "Python" Programming'

# %%
print(sent2)
# Out:
# I love "Python" Programming

# %%
a = 6
b = 8
c = a + b
print(c)
# Out:
# 14

# %%
a, b, c = 25, 6, "ok"

# %%
a
# Out:
# 25

# %%
b
# Out:
# 6

# %%
c
# Out:
# 'ok'
