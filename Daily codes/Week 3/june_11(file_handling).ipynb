# %%
f = open("sample.txt")

# %%
print(f)
# Out:
# <_io.TextIOWrapper name='sample.txt' mode='r' encoding='cp1252'>

# %%
f.readable()
# Out:
# True

# %%
f.readline()
# Out:
# 'A wiki is a form of hypertext publication on the internet which is collaboratively edited and managed by its audience directly through a web browser.\n'

# %%
f.readline()
# Out:
# 'A typical wiki contains multiple pages that can either be edited by the public or limited to use within an organization for maintaining its internal knowledge base. \n'

# %%
f.readline()
# Out:
# "The name derives from the first user-editable website called WikiWikiWeb â€“ wiki being a Hawaiian word meaning 'quick'"

# %%
f.readline()
# Out:
# ''

# %%
f = open("sample.txt")

# %%
f.readline(10)
# Out:
# 'A wiki is '

# %%
f.readline(5)
# Out:
# 'a for'

# %%
f.tell()
# Out:
# 15

# %%
f.seek(10)
# Out:
# 10

# %%
f.readline(5)
# Out:
# 'a for'

# %%
f = open("sample.txt")

# %%
data = f.readlines()

# %%
data
# Out:
# ['A wiki is a form of hypertext publication on the internet which is collaboratively edited and managed by its audience directly through a web browser.\n',
#  'A typical wiki contains multiple pages that can either be edited by the public or limited to use within an organization for maintaining its internal knowledge base. \n',
#  "The name derives from the first user-editable website called WikiWikiWeb â€“ wiki being a Hawaiian word meaning 'quick'"]

# %%
for line in data:
    print(line)
# Out:
# A wiki is a form of hypertext publication on the internet which is collaboratively edited and managed by its audience directly through a web browser.
#
# A typical wiki contains multiple pages that can either be edited by the public or limited to use within an organization for maintaining its internal knowledge base.
#
# The name derives from the first user-editable website called WikiWikiWeb â€“ wiki being a Hawaiian word meaning 'quick'

# %%
for line in data:
    print(line.upper())
# Out:
# A WIKI IS A FORM OF HYPERTEXT PUBLICATION ON THE INTERNET WHICH IS COLLABORATIVELY EDITED AND MANAGED BY ITS AUDIENCE DIRECTLY THROUGH A WEB BROWSER.
#
# A TYPICAL WIKI CONTAINS MULTIPLE PAGES THAT CAN EITHER BE EDITED BY THE PUBLIC OR LIMITED TO USE WITHIN AN ORGANIZATION FOR MAINTAINING ITS INTERNAL KNOWLEDGE BASE.
#
# THE NAME DERIVES FROM THE FIRST USER-EDITABLE WEBSITE CALLED WIKIWIKIWEB Â€“ WIKI BEING A HAWAIIAN WORD MEANING 'QUICK'

# %%
f = open("sample.txt")

# %%
text = f.read()

# %%
text
# Out:
# "A wiki is a form of hypertext publication on the internet which is collaboratively edited and managed by its audience directly through a web browser.\nA typical wiki contains multiple pages that can either be edited by the public or limited to use within an organization for maintaining its internal knowledge base. \nThe name derives from the first user-editable website called WikiWikiWeb â€“ wiki being a Hawaiian word meaning 'quick'"

# %%
print(text)
# Out:
# A wiki is a form of hypertext publication on the internet which is collaboratively edited and managed by its audience directly through a web browser.
# A typical wiki contains multiple pages that can either be edited by the public or limited to use within an organization for maintaining its internal knowledge base.
# The name derives from the first user-editable website called WikiWikiWeb â€“ wiki being a Hawaiian word meaning 'quick'

# %%
text.split()
# Out:
# ['A',
#  'wiki',
#  'is',
#  'a',
#  'form',
#  'of',
#  'hypertext',
#  'publication',
#  'on',
#  'the',
#  'internet',
#  'which',
#  'is',
#  'collaboratively',
#  'edited',
#  'and',
#  'managed',
#  'by',
#  'its',
#  'audience',
#  'directly',
#  'through',
#  'a',
#  'web',
#  'browser.',
#  'A',
#  'typical',
#  'wiki',
#  'contains',
#  'multiple',
#  'pages',
#  'that',
#  'can',
#  'either',
#  'be',
#  'edited',
#  'by',
#  'the',
#  'public',
#  'or',
#  'limited',
#  'to',
#  'use',
#  'within',
#  'an',
#  'organization',
#  'for',
#  'maintaining',
#  'its',
#  'internal',
#  'knowledge',
#  'base.',
#  'The',
#  'name',
#  'derives',
#  'from',
#  'the',
#  'first',
#  'user-editable',
#  'website',
#  'called',
#  'WikiWikiWeb',
#  'â€“',
#  'wiki',
#  'being',
#  'a',
#  'Hawaiian',
#  'word',
#  'meaning',
#  "'quick'"]

# %%
m = open('marathi.txt', encoding = 'utf-8')

# %%
print(m.read())
# Out:
# बृहदेश्वर मंदिर तथा तंजई पेरिया कोविल हे तंजावर, तमिळनाडू मध्ये कावेरी नदीच्या दक्षिण तीरावर स्थित भगवान शिवाला समर्पित द्रविड शैलीतील हिंदू मंदिर आहे.
# मंदिरास राजराजेश्वरम देखील म्हणले जाते. हे मंदिर जगातील सर्वात मोठ्या हिंदू मंदिरांपैकी एक आहे. विकसित तमिळ वास्तुकलेचे हे अनुकरणीय उदाहरण आहे, मंदिरास दक्षिणेचा मेरू असेही म्हणतात.
# हे मंदिर चोळ राजा राजराजा पहिला याने इ.स. १००३ ते १०१० या दरम्यान बांधले. या मंदिरासोबतच चोळ वंशाच्या काळातील गंगाईकोंडा चोलापुरम मंदिर आणि ऐरावतेश्वर मंदिर हे युनेस्कोच्या जागतिक वारसा स्थळाचा एक भाग आहे ज्याला "चोळ राजांची जिवंत भव्य मंदिरे (ग्रेट लिविंग चोला टेंपल्स)" म्हणून ओळखले जाते.

# %%
m.readable()
# Out:
# True

# %%
m.close()

# %%
m.readable()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 m.readable()
#
# ValueError: I/O operation on closed file

# %%
with open('sample.txt') as f:
    data = f.read()

# %%
print(data)
# Out:
# A wiki is a form of hypertext publication on the internet which is collaboratively edited and managed by its audience directly through a web browser.
# A typical wiki contains multiple pages that can either be edited by the public or limited to use within an organization for maintaining its internal knowledge base.
# The name derives from the first user-editable website called WikiWikiWeb â€“ wiki being a Hawaiian word meaning 'quick'

# %%
f = open('myfile.txt', 'w')

# %%
f.readable()
# Out:
# False

# %%
f.writable()
# Out:
# True

# %%
lines = ['frodo took the ring.', 'he started his journey to mount doom.' ]

# %%
f.writelines(lines)

# %%
f.close()

# %%
f = open('myfile.txt', 'w')

# %%
sent = "frodo took the ring. he started his journey to mount doom."

# %%
f.write(sent)
# Out:
# 58

# %%
f.close()

# %%
with open('myfile.txt', 'w') as f:
    f.write('This is first line\n')
    f.write('This is second line\n')
    f.write('This is third line\n')

# %%
s = open('sample.txt', 'r')
f = open('myfile.txt', 'w')

# %%
contents = s.read()
f.write(contents)
f.close()

# %%
s = open('sample.txt', 'a')

# %%
s.write('\ndone')
# Out:
# 5

# %%
s.close()
